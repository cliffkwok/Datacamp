# %% [markdown]
# ### Matplotlib Basic

# %% [markdown]
# <p>- Very Basic Construction</p>

# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

import pandas as pd
data = pd.read_csv('http://hilpisch.com/tr_eikon_eod_data.csv',
                  index_col=0, parse_dates=True).dropna()

# Supply x-axis and y-axis data (marker='v')
ax.plot(data.index, data['AAPL.O'],color='b', linestyle='-',linewidth=.5)
ax.plot(data.index, data['MSFT.O'],color='r', linestyle='--',linewidth=3)

# Customize the x-axis label
ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set_title("Title")

# Call the show function
plt.show()

# %%
data
# Out:
#                 AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX  \
# Date
# 2010-01-04   30.572827  30.950   20.88   133.90  173.08  113.33  1132.99
# 2010-01-05   30.625684  30.960   20.87   134.69  176.14  113.63  1136.52
# 2010-01-06   30.138541  30.770   20.80   132.25  174.26  113.71  1137.14
# 2010-01-07   30.082827  30.452   20.60   130.00  177.67  114.19  1141.69
# 2010-01-08   30.282827  30.660   20.83   133.52  174.31  114.57  1144.98
# ...                ...     ...     ...      ...     ...     ...      ...
# 2018-06-25  182.170000  98.390   50.71  1663.15  221.54  271.00  2717.07
# 2018-06-26  184.430000  99.080   49.67  1691.09  221.58  271.60  2723.06
# 2018-06-27  184.160000  97.540   48.76  1660.51  220.18  269.35  2699.63
# 2018-06-28  185.500000  98.630   49.25  1701.45  223.42  270.89  2716.31
# 2018-06-29  185.110000  98.610   49.71  1699.80  220.57  271.28  2718.37
#
#              .VIX    EUR=     XAU=    GDX     GLD
# Date
# ...

# %% [markdown]
# ### Matplotlib - Intermediate Python for Data Science

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('gapminder.csv',index_col='Unnamed: 0')

gdp_cap = df['gdp_cap']
life_exp = df['life_exp']
pop = df['population']
df.head()
df['col'] = 'r'
col = df['col']
df.head()
# Out:
#         country  year  population      cont  life_exp       gdp_cap col
# 11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338   r
# 23      Albania  2007   3600523.0    Europe    76.423   5937.029526   r
# 35      Algeria  2007  33333216.0    Africa    72.301   6223.367465   r
# 47       Angola  2007  12420476.0    Africa    42.731   4797.231267   r
# 59    Argentina  2007  40301927.0  Americas    75.320  12779.379640   r

# %%
# Scatter plot
#plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha = 0.8)
plt.scatter(x = gdp_cap, y = life_exp, c = col, s =np.array(pop)*.000001, alpha = 0.5)
# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### Subplots

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(1,10,10)
b = a**2

# %%
# plt.subplot(nrows, ncols, plot number)
plt.subplot(1,2,1)
plt.plot(a,b,'b--');

# %%
# plt.subplot(nrows, ncols, plot number)
plt.subplot(1,2,2)
plt.plot(b,a,'r*-');

# %% [markdown]
# ### Matplot Setting

# %%
import numpy as np
import pandas as pd
a = np.arange(12).reshape((4,3))
date = pd.date_range('2019-1-1',periods=4, freq='B')
col = list('abc')
df = pd.DataFrame(a, columns=col, index=date)
df
# Out:
#             a   b   c
# 2019-01-01  0   1   2
# 2019-01-02  3   4   5
# 2019-01-03  6   7   8
# 2019-01-04  9  10  11

# %%
# %matplotlib inline
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'arial'
df.plot();

# %% [markdown]
# ### Matplotlib - Pandas foundation

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
# Print the minimum value of the Engineering column
print(df['Engineering'].min())

# Print the maximum value of the Engineering column
print(df['Engineering'].max())

df.head(1)
# Out:
# 0.8
# 19.0
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363  9.064439
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
#
#    Social Sciences and History
# 0                         36.8

# %%
# Construct the mean percentage per year: mean -> across all columns per row
mean = df.mean(axis='columns')
print(mean)
# Plot the average percentage per year
mean.plot()

# Display the plot
plt.show()
# Out:
# 0     145.894992
# 1     145.958843
# 2     146.451293
# 3     147.513392
# 4     149.065032
# 5     149.741801
# 6     151.348049
# 7     152.969722
# 8     154.569299
# 9     156.044476
# 10    157.203884
# 11    158.197752
# 12    159.231146
# 13    159.454766
# 14    159.781007
# 15    159.766240
# 16    160.155451
# 17    160.604810
# 18    160.623377
# 19    160.844123
# 20    161.307511
# 21    161.112087
# 22    160.970044
# 23    160.965913
# 24    161.058514
# 25    161.369045
# 26    161.833695
# 27    162.366566
# 28    163.159018
# 29    163.917564
# 30    164.474053
# 31    164.949862
# 32    165.227182
# 33    165.458234
# 34    165.184700
# 35    164.961350
# 36    164.580961
# 37    164.439682
# 38    164.353706
# 39    164.524939
# 40    164.445096
# 41    164.610721
# dtype: float64
